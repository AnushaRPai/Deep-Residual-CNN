# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install spectral

# %%
import spectral.io.envi as envi
import cv2  
import numpy as np
import imageio 
from PIL import Image, ImageFilter
import scipy
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
y_train = []
x_train = []
x_test = []
y_test = []

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/balloons_ms/balloons_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/balloons_ms/Down2/balloons_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/beads_ms/beads_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/beads_ms/Down2/beads_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/cd_ms/cd_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cd_ms/Down2/cd_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms/chart_and_stuffed_toy_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/chart_and_stuffed_toy_ms/Down2/chart_and_stuffed_toy_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/clay_ms/clay_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/clay_ms/Down2/clay_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/cloth_ms/cloth_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/cloth_ms/Down2/cloth_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/egyptian_statue_ms/egyptian_statue_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/egyptian_statue_ms/Down2/egyptian_statue_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/face_ms/face_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/face_ms/Down2/face_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/fake_and_real_beers_ms/fake_and_real_beers_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_beers_ms/Down2/fake_and_real_beers_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/fake_and_real_food_ms/fake_and_real_food_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_food_ms/Down2/fake_and_real_food_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms/fake_and_real_lemon_slices_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemon_slices_ms/Down2/fake_and_real_lemon_slices_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/fake_and_real_lemons_ms/fake_and_real_lemons_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_lemons_ms/Down2/fake_and_real_lemons_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/fake_and_real_peppers_ms/fake_and_real_peppers_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_peppers_ms/Down2/fake_and_real_peppers_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms/fake_and_real_strawberries_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_strawberries_ms/Down2/fake_and_real_strawberries_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/fake_and_real_sushi_ms/fake_and_real_sushi_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/fake_and_real_sushi_ms/Down2/fake_and_real_sushi_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/feathers_ms/feathers_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/feathers_ms/Down2/feathers_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/flowers_ms/flowers_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/flowers_ms/Down2/flowers_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/glass_tiles_ms/glass_tiles_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/glass_tiles_ms/Down2/glass_tiles_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/hairs_ms/hairs_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/hairs_ms/Down2/hairs_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/jelly_beans_ms/jelly_beans_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/jelly_beans_ms/Down2/jelly_beans_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/oil_painting_ms/oil_painting_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/oil_painting_ms/Down2/oil_painting_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/paints_ms/paints_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/paints_ms/Down2/paints_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/photo_and_face_ms/photo_and_face_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/photo_and_face_ms/Down2/photo_and_face_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/pompoms_ms/pompoms_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/pompoms_ms/Down2/pompoms_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/real_and_fake_apples_ms/real_and_fake_apples_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_apples_ms/Down2/real_and_fake_apples_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/real_and_fake_peppers_ms/real_and_fake_peppers_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/real_and_fake_peppers_ms/Down2/real_and_fake_peppers_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/sponges_ms/sponges_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/sponges_ms/Down2/sponges_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/stuffed_toys_ms/stuffed_toys_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/stuffed_toys_ms/Down2/stuffed_toys_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/superballs_ms/superballs_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/superballs_ms/Down2/superballs_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/thread_spools_ms/thread_spools_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_train.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/thread_spools_ms/Down2/thread_spools_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_train.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/watercolors_ms/watercolors_ms_31.png',0)
img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
y_test.append(img)

img1 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_01.png',0)
img2 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_02.png',0)
img3 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_03.png',0)
img4 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_04.png',0)
img5 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_05.png',0)
img6 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_06.png',0)
img7 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_07.png',0)
img8 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_08.png',0)
img9 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_09.png',0)
img10 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_10.png',0)
img11 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_11.png',0)
img12 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_12.png',0)
img13 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_13.png',0)
img14 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_14.png',0)
img15 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_15.png',0)
img16 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_16.png',0)
img17 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_17.png',0)
img18 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_18.png',0)
img19 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_19.png',0)
img20 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_20.png',0)
img21 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_21.png',0)
img22 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_22.png',0)
img23 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_23.png',0)
img24 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_24.png',0)
img25 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_25.png',0)
img26 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_26.png',0)
img27 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_27.png',0)
img28 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_28.png',0)
img29 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_29.png',0)
img30 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_30.png',0)
img31 = cv2.imread(r'/content/drive/MyDrive/CAVE dataset/watercolors_ms/Down2/watercolors_ms_31.png',0)

img1 = np.array(img1)
img1 = np.reshape(img1,(img1.shape[0],img1.shape[1],1))
img2 = np.array(img2)
img2 = np.reshape(img2,(img2.shape[0],img2.shape[1],1))
img3 = np.array(img3)
img3 = np.reshape(img3,(img3.shape[0],img3.shape[1],1))
img4 = np.array(img4)
img4 = np.reshape(img4,(img4.shape[0],img4.shape[1],1))
img5 = np.array(img5)
img5 = np.reshape(img5,(img5.shape[0],img5.shape[1],1))
img6 = np.array(img6)
img6 = np.reshape(img6,(img6.shape[0],img6.shape[1],1))
img7 = np.array(img7)
img7 = np.reshape(img7,(img7.shape[0],img7.shape[1],1))
img8 = np.array(img8)
img8 = np.reshape(img8,(img1.shape[0],img8.shape[1],1))
img9 = np.array(img9)
img9 = np.reshape(img9,(img1.shape[0],img9.shape[1],1))
img10 = np.array(img10)
img10 = np.reshape(img10,(img1.shape[0],img10.shape[1],1))
img11 = np.array(img11)
img11 = np.reshape(img11,(img1.shape[0],img11.shape[1],1))
img12 = np.array(img12)
img12 = np.reshape(img12,(img1.shape[0],img12.shape[1],1))
img13 = np.array(img13)
img13 = np.reshape(img13,(img1.shape[0],img13.shape[1],1))
img14 = np.array(img14)
img14 = np.reshape(img14,(img1.shape[0],img14.shape[1],1))
img15 = np.array(img15)
img15 = np.reshape(img15,(img1.shape[0],img15.shape[1],1))
img16 = np.array(img16)
img16 = np.reshape(img16,(img1.shape[0],img16.shape[1],1))
img17 = np.array(img17)
img17 = np.reshape(img17,(img1.shape[0],img17.shape[1],1))
img18 = np.array(img18)
img18 = np.reshape(img18,(img1.shape[0],img18.shape[1],1))
img19 = np.array(img19)
img19 = np.reshape(img19,(img1.shape[0],img19.shape[1],1))
img20 = np.array(img20)
img20 = np.reshape(img20,(img1.shape[0],img20.shape[1],1))
img21 = np.array(img21)
img21 = np.reshape(img21,(img1.shape[0],img21.shape[1],1))
img22 = np.array(img22)
img22 = np.reshape(img22,(img1.shape[0],img22.shape[1],1))
img23 = np.array(img23)
img23 = np.reshape(img23,(img1.shape[0],img23.shape[1],1))
img24 = np.array(img24)
img24 = np.reshape(img24,(img1.shape[0],img24.shape[1],1))
img25 = np.array(img25)
img25 = np.reshape(img25,(img1.shape[0],img25.shape[1],1))
img26 = np.array(img26)
img26 = np.reshape(img26,(img1.shape[0],img26.shape[1],1))
img27 = np.array(img27)
img27 = np.reshape(img27,(img1.shape[0],img27.shape[1],1))
img28 = np.array(img28)
img28 = np.reshape(img28,(img1.shape[0],img28.shape[1],1))
img29 = np.array(img29)
img29 = np.reshape(img29,(img1.shape[0],img29.shape[1],1))
img30 = np.array(img30)
img30 = np.reshape(img30,(img1.shape[0],img10.shape[1],1))
img31 = np.array(img31)
img31 = np.reshape(img31,(img1.shape[0],img11.shape[1],1))
img = np.concatenate((img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13,img14,img15,img16),2)
img = np.concatenate((img,img17,img18,img19,img20,img21,img22,img23,img24,img25,img26,img27,img28,img29,img30,img31),2)
print(img.shape)
x_test.append(img)
# Out:
# (512, 512, 31)
# (512, 512, 31)

# %%
print(np.shape(x_train))
print(np.shape(y_train))
print(np.shape(x_test))
print(np.shape(y_test))
x_train = np.array(x_train,dtype = 'float32')

y_train = np.array(y_train,dtype = 'float32')

x_test = np.array(x_test,dtype = 'float32')
y_test = np.array(y_test,dtype = 'float32')
x_train1 = x_train[0:2]
y_train1 = y_train[0:2]
print(np.shape(x_train))
print(np.shape(y_train))
print(np.shape(x_test))
print(np.shape(y_test))
# Out:
# (31, 512, 512, 31)
# (31, 512, 512, 31)
# (1, 512, 512, 31)
# (1, 512, 512, 31)
# (31, 512, 512, 31)
# (31, 512, 512, 31)
# (1, 512, 512, 31)
# (1, 512, 512, 31)

# %%
print(np.shape(x_train[0]))
# Out:
# (512, 512, 31)

# %%
#the loss function
def the_loss_fuction(y,y1):
    #mean square error
    l1 = sum(np.square(y-y1))
    #SAP
    l2 = np.inner(y,y1)
    l2 = l2/(np.linalg.det(y)*np.linalg.det(y1))
    a = 0.5
    return a*l1 + (1-a)*l2

# %%
input = tf.keras.Input(shape=np.shape(x_train)[1:])

# Block 1
x_skip1 = input
x1 = tf.keras.layers.Conv2D(96, (9,9), padding = "same", activation="relu")(input)
x1 = tf.keras.layers.Conv2D(54, (3,3), padding = "same", activation="relu")(x1)
x1 = tf.keras.layers.Conv2D(31, (5,5), padding = "same", activation="relu")(x1)
x1 = tf.keras.layers.Add()([x1, x_skip1])

x_skip2 = x1
x2 = tf.keras.layers.Conv2D(96, (9,9), padding = "same", activation="relu")(x1)
x2 = tf.keras.layers.Conv2D(54, (3,3), padding = "same", activation="relu")(x2)
x2 = tf.keras.layers.Conv2D(31, (5,5), padding = "same", activation="relu")(x2)
x2 = tf.keras.layers.Add()([x2, x_skip2])

x_skip3 = x2
x3 = tf.keras.layers.Conv2D(96, (9,9), padding = "same", activation="relu")(x2)
x3 = tf.keras.layers.Conv2D(54, (3,3), padding = "same", activation="relu")(x3)
x3 = tf.keras.layers.Conv2D(31, (5,5), padding = "same", activation="relu")(x3)
x3 = tf.keras.layers.Add()([x3, x_skip3])

x_skip4 = x3
x4 = tf.keras.layers.Conv2D(96, (9,9), padding = "same", activation="relu")(x3)
x4 = tf.keras.layers.Conv2D(54, (3,3), padding = "same", activation="relu")(x4)
x4 = tf.keras.layers.Conv2D(31, (5,5), padding = "same", activation="relu")(x4)
x4 = tf.keras.layers.Add()([x4, x_skip4])

x_skip5 = x4
x5 = tf.keras.layers.Conv2D(96, (9,9), padding = "same", activation="relu")(x4)
x5 = tf.keras.layers.Conv2D(54, (3,3), padding = "same", activation="relu")(x5)
x5 = tf.keras.layers.Conv2D(31, (5,5), padding = "same", activation="relu")(x5)
x5 = tf.keras.layers.Add()([x5, x_skip5])

x_skip6 = x5
x6 = tf.keras.layers.Conv2D(96, (9,9), padding = "same", activation="relu")(x5)
x6 = tf.keras.layers.Conv2D(54, (3,3), padding = "same", activation="relu")(x6)
x6 = tf.keras.layers.Conv2D(31, (5,5), padding = "same", activation="relu")(x6)
x6 = tf.keras.layers.Add()([x6, x_skip6])


output = x6

# bind all
func_model = tf.keras.Model(input, output)
func_model.compile(optimizer='sgd',
              loss=tf.keras.losses.MeanSquaredLogarithmicError())
func_model.fit(x_train1, y_train1, epochs=2)
y = func_model.predict(x_test)
func_model.summary()
# Out:
# Epoch 1/2
# 1/1 [==============================] - 144s 144s/step - loss: 2.3991
# Epoch 2/2
# 1/1 [==============================] - 146s 146s/step - loss: 0.6868
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 1)]
#
#  conv2d (Conv2D)                (None, 512, 512, 96  241152      ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 54  46710       ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 31  41881       ['conv2d_1[0][0]']
#                                 )
#
#  add (Add)                      (None, 512, 512, 31  0           ['conv2d_2[0][0]',
# ...

# %%
i = y[0]
i[:,:,:3].shape
plt.imshow(i[:,:,:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
